# %%
words = ["1000gbp", "$37", "notanumber", "-1000indebt"]
def hasNumbers(inputString):
    return any(char.isdigit() for char in inputString)

hasNumbers(words[-1])
# Out:
# False

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
#label the data

data = []
data_labels = []
with open("pos_tweets.txt") as f:
    for i in f:
        data.append(i.strip())
        data_labels.append("pos")

with open("neg_tweets.txt") as f:
    for i in f:
        data.append(i.strip())
        data_labels.append("neg")

# %%
#clean the data
def remove_user_handles():
    for i in range(len(data)):
        if "@" in data[i]:
            nonUserHandleWords = []
            words = data[i].split(" ")
            for j in range(len(words)):
                if "@" not in words[j]:
                    nonUserHandleWords.append(words[j])
            data[i] = " ".join(nonUserHandleWords)
            
def remove_numbers_from_sentences():
    for i in range(len(data)):
        if 

remove_user_handles()

# %%
# Vectorization: the general process of turning a collection of text documents into numerical feature vectors
vectorizer = CountVectorizer(analyzer="word", lowercase=False)

features = vectorizer.fit_transform(data)
features_nd = features.toarray()
print(vectorizer.get_feature_names())
# Out:
# ['00', '000', '000GBP', '00am', '06', '06H8T', '08Tv6', '09', '0GB', '10', '100', '101', '102', '10k', '11', '111', '11vcij', '12', '1205308493', '123', '12th', '13', '130', '14', '15', '150', '15th', '16', '160', '16BoLQ', '16GB', '17', '17NsuD', '17nwOf', '17th', '19th', '1XTTi', '1a7zPw', '1b', '1pm', '1st', '20', '200', '2009', '2010', '209', '20th', '22', '228', '23', '231', '24', '24hrs', '25', '25th', '260', '28', '28th', '29823782', '2Nite', '2day', '2k9', '2morrow', '2nd', '2night', '2nite', '2y36e', '2y5xp', '30', '3000', '301', '30am', '320', '32Gb', '35', '360', '371', '38', '395031', '39am', '3D', '3G', '3GS', '3MK', '3am', '3lzt1', '3rd', '3turnoffwords', '3yr', '40', '400', '404', '42', '439', '447', '45', '48', '49', '4am', '4pm', '4th', '50', '51am', '5248435', '530', '536', '56m0y', '57', '58', '5PM', '5am', '5c9gs', '5oll7', '5th', '5yr', '5º', '62', '640km', '642', '6JW9f', '6am', '6idya', '6q1om', '6r413', '6ubr9', '6vb49', '70s', '72', '74', '75', '7GU8A', '7e01t', '7gteh', '7hr45mins', '7pf62', '7pm', '7w83x', '85', '8GB', '8gb', '8th', '8yr', '96', '98', '9am', '9th', 'ABC', 'ABOUT', 'AC', 'ADVANCE', 'AFcrash', 'AGAIN', 'AIDS', 'ALL', 'ALWAYS', 'AM', 'AMAZING', 'AND', 'ANWB', 'API', 'ARE', 'ARENT', 'ARGHHH', 'AROUND', 'AT', 'ATM', 'AUSTRALIA', 'AWAY', 'AWESOME', 'AY4Eu', 'Abbie', 'About', 'Absoluty', 'Achmed', 'Action', 'Actress', 'Adams', 'Add', 'Adding', 'Adelaide', 'Advanced', 'Aerius', 'Affliction', 'Afrin', 'After', 'Afternoon', 'Again', 'Ah', 'Ahh', 'Ahhhhhh', 'Ahmedinejad', 'Air', 'Airborne', 'Alex', 'Aliens', 'All', 'Allen', 'Allerfre', 'Allergies', 'Alliance', 'Also', 'Aly', 'Am', 'Amazing', 'Amen', 'America', 'American', 'Amity', 'Amy', 'An', 'Ana', 'Anaheim', 'Anchorman', 'And', 'Anderson', 'Andrew', 'Angel', 'Announcement', 'Annoying', 'Another', 'Anti', 'Anybdy', 'Anybody', 'Anyone', 'Anyway', 'Apparently', 'Apple', 'Apps', 'April', 'Aquarium', 'Are', 'Argentina', 'Argh', 'Arm', 'Arrived', 'As', 'Ash', 'Ashes', 'Ashton', 'Astronaut', 'At', 'Atlantic', 'Attending', 'August', 'Aussie', 'Austin', 'Australia', 'Aw', 'Away', 'Awesome', 'Aww', 'Awwww', 'Awwwww', 'Awwwwwww', 'BABY', 'BABYY', 'BAN', 'BBC', 'BBC2', 'BEAT', 'BED', 'BFF', 'BFFL', 'BGT', 'BIG', 'BOO', 'BOOOOO', 'BOREEEEEEEEEEEEEEEEEEENG', 'BRAZIL', 'BREAKING', 'BROWNS', 'BTW', 'BURROWISH', 'BUT', 'Baby', 'Back', 'Bad', 'Bah', 'Baker', 'Ballads', 'Band', 'Bangalore', 'Barack', 'Barcelona', 'Beach', 'Bear', 'Beast', 'Beat', 'Beatles', 'Beautiful', 'Because', 'Becca', 'Bed', 'Bedtime', 'Been', 'Beer', 'Being', 'Bell', 'Bellevue', 'Belong', 'Bennett', 'Benny', 'Bentley', 'Beso', 'Best', 'Bet', 'Betsey', 'Better', 'Beware', 'Beyonce', 'Beyond', 'Bidding', 'Billie', 'Birhtday', 'Birthay', 'Birthday', 'Bjork', 'Blackberry', 'Blake', 'Bleu', 'Bloody', 'Blue', 'Boba', 'Bobby', 'Bock', 'Bold', 'BonJour', 'Bondi', 'Boo', 'Booo', 'Bored', 'Both', 'Bother', 'Boxer', 'Boy', 'Brazil', 'Brazilian', 'Break', 'Breakfast', 'Breast', 'Brian', 'Brians', 'Bridge', 'Bring', 'Bris', 'Brisvegas', 'Broadband', 'Broke', 'Bron', 'Brothers', 'Bryce', 'Btw', 'Buck', 'Bummer', 'Bungie', 'Burned', 'Burnt', 'But', 'By', 'Bye', 'CA', 'CAN', 'CANT', 'CASH', 'CAVS', 'CAvS', 'CD', 'CFA', 'CHAT', 'CL', 'COD', 'COME', 'COOL', 'CR', 'CRYINGGG', 'Cairo', 'Cake', 'Calgary', 'Call', 'Callin', 'Came', 'Camp', 'Can', 'Canada', 'Canberra', 'Cancer', 'Cant', 'Canucks', 'Capcom', 'Car', 'Cardiff', 'Carmel', 'Carradine', 'Carrie', 'Catherine', 'Cavs', 'Celebrate', 'Celebrating', 'Cellos', 'Celsius', 'Celtics', 'Celts', 'Championship', 'Channel', 'Charging', 'Charming', 'Cheeseburger', 'Chelsea', 'Chicago', 'ChickHEN', 'Chile', 'Chinese', 'Chirs', 'Choclate', 'Choice', 'Chris', 'Chrisette', 'Chuckle', 'City', 'Clarkson', 'Class', 'Cleaning', 'Cleveland', 'Club', 'Cocktail', 'Coco', 'Coffee', 'Coke', 'Coleman', 'College', 'Colorado', 'Come', 'Committee', 'Comp', 'Company', 'Completed', 'Completely', 'Congrat', 'Congrats', 'Congratulations', 'Contest', 'Convention', 'Cook', 'Cookin', 'C ...

# %%
X_train, X_test, y_train, y_test = train_test_split(features_nd, data_labels, train_size=0.80, random_state=1234)

# %%
#Create a model
log_model = LogisticRegression()
log_model = log_model.fit(X=X_train, y=y_train)

# %%
#Predict positive or negative for our test dataset 
y_pred = log_model.predict(X_test)

# %%
def getPrediction(index):
    ind = features_nd.tolist().index(X_test[index].tolist())
    print("The prediction for the sentence " + data[ind] + " is " + y_pred[index] + " . The true sentiment is " + y_test[index])

# %%
getPrediction(5)
# Out:
# The prediction for the sentence "Listening to Ana Free =D love you Ana.  From brazil"
#  is pos . The true sentiment is pos
